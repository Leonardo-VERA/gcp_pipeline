# %%
#pip install gdown
import gdown

gdown.download_folder(
    id="15vJu5-gSPVIVfp2zMyviqyxBxWXjv8Y4",
    output="mon_dossier",
    quiet=False,
    use_cookies=False
)
# Out:
# Retrieving folder contents
# Processing file 1v-FwPf52K24tIqIfZshafnJiXozP_uhH HR_Data.xlsx
# Retrieving folder contents completed
# Building directory structure
# Building directory structure completed
# Downloading...
# From: https://drive.google.com/uc?id=1v-FwPf52K24tIqIfZshafnJiXozP_uhH
# To: /root/code/Leonardo-VERA/gcp_pipeline/data/processed/mon_dossier/HR_Data.xlsx
# 100%|██████████| 284k/284k [00:00<00:00, 2.83MB/s]
# Download completed
# ['mon_dossier/HR_Data.xlsx']

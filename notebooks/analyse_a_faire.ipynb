# %%
import pandas as pd

# %%
df = pd.read_csv("../data/raw/apps.csv.zip")
df.head()
# Out:
#                                      id  \
# 0  863705e9-45ae-4cd4-abe6-447aa903888d
# 1  883f7885-706c-4c4b-bce1-c29c119d40f7
# 2  a04928a5-ee0a-4f42-877c-38ddb17c88ec
# 3  df08d502-9d22-4a88-9b16-f563ee407781
# 4  6f0424c0-1c90-4663-a8b1-fb485d28ba55
#
#                                                  url  \
# 0               https://apps.shopify.com/manysingles
# 1         https://apps.shopify.com/activitytracker-1
# 2       https://apps.shopify.com/elfsight-file-embed
# 3  https://apps.shopify.com/import-products-from-...
# 4             https://apps.shopify.com/aod-easy-tabs
#
#                       title        developer  \
# 0               ManySingles  Vanessa Company
# 1   Real‑Time Shop Insights         Breinify
# 2       Elfsight File Embed         Elfsight
# 3               Json import          Dalibor
# 4  Product Tabs ‑ Easy Tabs   Apps On Demand
#
#                                       developer_link  \
# 0  https://apps.shopify.com/partners/vanessa-company
# ...

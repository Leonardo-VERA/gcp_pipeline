# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# Running cells with '.venv (3.10.12) (Python 3.10.12)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: '/root/code/Leonardo-VERA/gcp_pipeline/.venv/bin/python -m pip install ipykernel -U --force-reinstall'

# %%
df_products = pd.read_csv('../data/processed/products.csv')
df_variants = pd.read_csv('../data/processed/variants.csv')
df_customers = pd.read_csv('../data/processed/customers.csv')

# %%
print("📦 PRODUITS")
print(df_products.shape)
df_products.head()

# %%
print("💰 VARIANTS")
print(df_variants.shape)
df_variants.head()

# %%
print("👥 CLIENTS")
print(df_customers.shape)
df_customers.head()

# %%
print("📊 Types de données - Produits")
df_products.info()
